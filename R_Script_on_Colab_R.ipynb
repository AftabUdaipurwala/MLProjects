# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/MLProjects/blob/main/R_Script_on_Colab_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Creating R Script on Google Colab

# %%
print(installed.packages())

# %%
install.packages("keras")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘png’, ‘config’, ‘tfautograph’, ‘reticulate’, ‘tensorflow’, ‘tfruns’, ‘zeallot’

# %%
library(keras)

# %%
data <- read.csv('/content/sample_data/california_housing_train.csv', header = T)

# %%
head(data)
# Out:
#   longitude latitude housing_median_age total_rooms total_bedrooms population
# 1 -114.31   34.19    15                 5612        1283           1015
# 2 -114.47   34.40    19                 7650        1901           1129
# 3 -114.56   33.69    17                  720         174            333
# 4 -114.57   33.64    14                 1501         337            515
# 5 -114.57   33.57    20                 1454         326            624
# 6 -114.58   33.63    29                 1387         236            671
#   households median_income median_house_value
# 1 472        1.4936        66900
# 2 463        1.8200        80100
# 3 117        1.6509        85700
# 4 226        3.1917        73400
# 5 262        1.9250        65500
# 6 239        3.3438        74000

# %%
plot(hist(data$median_house_value))
# Out:
# Plot with title “Histogram of data$median_house_value”
# Plot with title “Histogram of data$median_house_value”

# %%
model = lm(median_house_value~., data = data)

# %%
summary(model)
# Out:
# Call:
# lm(formula = median_house_value ~ ., data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -565474  -43649  -11525   30220  801097
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -3.621e+06  6.921e+04 -52.312  < 2e-16 ***
# longitude          -4.314e+04  7.896e+02 -54.637  < 2e-16 ***
# latitude           -4.293e+04  7.458e+02 -57.556  < 2e-16 ***
# housing_median_age  1.151e+03  4.758e+01  24.186  < 2e-16 ***
# total_rooms        -8.378e+00  8.628e-01  -9.711  < 2e-16 ***
# total_bedrooms      1.176e+02  7.687e+00  15.305  < 2e-16 ***
# population         -3.849e+01  1.186e+00 -32.456  < 2e-16 ***
# households          4.544e+01  8.445e+00   5.380 7.54e-08 ***
# median_income       4.051e+04  3.682e+02 110.022  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 69480 on 16991 degrees of freedom
# ...

# %% [markdown]
# # ***Model seems to be at 64% R sq value ***
